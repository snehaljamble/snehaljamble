# %% [markdown]
# Q1)List functions

# %%
List =["Hii",2,4,5]
print(List)
# Out:
# ['Hii', 2, 4, 5]

# %%
List.append(7)

# %%
print(List)
# Out:
# ['Hii', 2, 4, 5, 7]

# %%
List1=List.copy()
print(List1)
# Out:
# ['Hii', 2, 4, 5]

# %%
List.count("Hii")
# Out:
# 1

# %%
List.append("Hii")
print(List)
# Out:
# ['Hii', 2, 4, 5, 7, 'Hii']

# %%
List.count("Hii")
# Out:
# 2

# %%
List.extend(List1)
print(List)
# Out:
# ['Hii', 2, 4, 5, 'Hii', 2, 4, 5]

# %%
List1.index("Hii")
# Out:
# 0

# %%
List.index(4)
# Out:
# 2

# %%
List1.insert(3,"Hello")
print(List1)
# Out:
# ['Hii', 2, 4, 'Hello', 5]

# %%
List1.remove(2)
print(List1)
# Out:
# ['Hii', 4, 'Hello', 5]

# %%
print(List1)
# Out:
# ['Hii', 4, 'Hello', 5]

# %%
List1.pop(2)
print(List1)
# Out:
# ['Hii', 4, 5]

# %%
List1.reverse()
print(List1)
# Out:
# [5, 4, 'Hii']

# %%
print(List)
# Out:
# ['Hii', 2, 4, 5, 7, 'Hii', 'Hii', 2, 4, 5, 7]

# %%
List.remove("Hii")

# %%
print(List)
# Out:
# [2, 4, 5, 7, 'Hii', 'Hii', 2, 4, 5, 7]

# %%
List.remove("Hii")
print(List)
# Out:
# [2, 4, 5, 7, 'Hii', 2, 4, 5, 7]

# %%
List.remove("Hii")
print(List)
# Out:
# [2, 4, 5, 7, 2, 4, 5, 7]

# %%
List.sort()
print(List)
# Out:
# [2, 2, 4, 4, 5, 5, 7, 7]

# %%
print(List1)
# Out:
# [5, 'Hello', 2, 'Hii']

# %%
List1.clear()

# %%
print(List1)
# Out:
# []

# %% [markdown]
# Q2)Directory functions

# %%
Navnath={'Name':'Navnath','class':'TYBCS','Location':'pune'}

# %%
Navnath.get('Name')
# Out:
# 'Navnath'

# %%
Navnath.values()
# Out:
# dict_values(['Navnath', 'TYBCS', 'pune'])

# %%
Navnath.keys()
# Out:
# dict_keys(['Name', 'class', 'Location'])

# %%
Navnath.items()
# Out:
# dict_items([('Name', 'Navnath'), ('class', 'TYBCS'), ('Location', 'pune')])

# %%
Navnath.fromkeys('Name','Navnath')
# Out:
# {'N': 'Navnath', 'a': 'Navnath', 'e': 'Navnath', 'm': 'Navnath'}

# %%
Navnath.copy()
# Out:
# {'Location': 'pune', 'Name': 'Navnath', 'class': 'TYBCS'}

# %%
Navnath.pop('Location')
# Out:
# 'pune'

# %%
Navnath.get('class')
# Out:
# 'TYBCS'

# %%
Navnath.get('classs','FYBCS')
# Out:
# 'FYBCS'

# %%
Navnath.keys()
# Out:
# dict_keys(['Name', 'class'])

# %%
Navnath.items()
# Out:
# dict_items([('Name', 'Navnath'), ('class', 'TYBCS')])

# %%
Navnath.popitem()
# Out:
# ('class', 'TYBCS')

# %%
Navnath.copy()
# Out:
# {'Name': 'Navnath'}

# %%
Python={'one':'PYPY','two':'PIPI'}

# %%
Navnath.update(Python)
Navnath.values()
# Out:
# dict_values(['Navnath', 'PYPY', 'PIPI'])

# %%
Navnath.setdefault('one')
# Out:
# 'PYPY'

# %%
Navnath.setdefault('thr','hello')
# Out:
# 'hello'

# %%
Navnath.values()
# Out:
# dict_values(['Navnath', 'PYPY', 'PIPI', 'hello'])

# %%
Python.clear()

# %% [markdown]
# Q3)Set functions

# %%
set1 = {34,67,89,12,54,34}

# %%
set2 ={1,2,3,4,5}

# %%
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 4, 5, 67, 12, 89, 34, 54}

# %%
set1.add(10)

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 10, 12, 34, 54, 67, 89}

# %%
set1.add(4)

# %%
set1.intersection(set2)
# Out:
# {4}

# %%
set1.difference(set2)
# Out:
# {10, 12, 34, 54, 67, 89}

# %%
set1.difference_update(set2)

# %%
set1.difference(set2)
# Out:
# {10, 12, 34, 54, 67, 89}

# %%
set1.copy()
# Out:
# {10, 12, 34, 54, 67, 89}

# %%
set1.add(100)
set1.copy()
# Out:
# {10, 12, 34, 54, 67, 89, 100}

# %%
set1.difference_update(set2)
set1.copy()
# Out:
# {10, 12, 34, 54, 67, 89, 100}

# %%
set2.add(500)
set2.copy()
# Out:
# {1, 2, 3, 4, 5, 500}

# %%
set2.difference(set1)
# Out:
# {1, 2, 3, 4, 5, 500}

# %%
set1.difference_update(set2)

# %%
set1.copy()
# Out:
# {10, 12, 34, 54, 67, 89, 100}

# %%
set1.intersection(set2)
# Out:
# {100}

# %%
set2.add(100)

# %%
set1.intersection_update(set2)

# %%
set1.isdisjoint(set2)
# Out:
# False

# %%
set1.issubset(set2)
# Out:
# True

# %%
set2.discard(100)

# %%
set2.copy()
# Out:
# {1, 2, 3, 4, 5}

# %%
set2.clear()

# %%
set2.copy()
# Out:
# set()

# %%
set1.copy()
# Out:
# {100}

# %%
set1.remove(100)

# %%
set1.copy()
# Out:
# set()

# %% [markdown]
# Q4)Touple methods

# %%
T=(1,2,3,4)
print(T)
# Out:
# (1, 2, 3, 4)

# %%
type(T)
# Out:
# tuple

# %%
T.count(1)
# Out:
# 1

# %%
T.index(3)
# Out:
# 2

# %% [markdown]
# Q5)String methods

# %%
S="Hello Snehal Good night sweet dream Take Care"
print(S)
# Out:
# Hello Snehal Good night sweet dream Take Care

# %%
type(S)
# Out:
# str

# %%
A="aarya"
A.capitalize()
# Out:
# 'Aarya'

# %%
S.replace('Snehal','Aarya')
# Out:
# 'Hello Aarya Good night sweet dream Take Care'

# %%
S.swapcase()
# Out:
# 'hELLO sNEHAL gOOD NIGHT SWEET DREAM tAKE cARE'

# %%
S.title()
# Out:
# 'Hello Snehal Good Night Sweet Dream Take Care'

# %%
S.upper()
# Out:
# 'HELLO SNEHAL GOOD NIGHT SWEET DREAM TAKE CARE'

# %%
S.lower()
# Out:
# 'hello snehal good night sweet dream take care'

# %%
S.find('Snehal')
# Out:
# 6

# %%
S.find('Aarya')
# Out:
# -1
