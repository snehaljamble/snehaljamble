# %% [markdown]
# Assignment 1

# %%
def getin(fibonaci):
  def wrap_funct():
    print("Fibonacci series")
    num=int(input("Enter the number of terms:"))
    fibonaci(num)
  return wrap_funct()

# %%
@getin
def fibo(n):
  n1=0
  n2=1
  for i in range(1,n+1):
      print(n1)
      Nn=n1+n2
      n1=n2
      n2=Nn
# Out:
# Fibonacci series
# Enter the number of terms:6
# 0
# 1
# 1
# 2
# 3
# 5

# %% [markdown]
# Assignment No 2

# %%
f=open("file.txt","r")		#opening file for reading and printing data

print("File opened mode:",f.mode)

content=f.read()
print('\n*********Data from file file.txt******\n',content)

try:
	str=input("Enter data to write in file:")
	for i in range(5):
 		f.write("%s\n"%str)
except :
		print("Exception occured while writing into file opening in read only mode")
